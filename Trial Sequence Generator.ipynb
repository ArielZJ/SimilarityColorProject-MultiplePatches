# %%
# script to generate the trial sequence list for the mixed colour patch task
# n stimuli
# y trial types: in this case y = 3 with during, after1, after2
# k catch trials
# grouping into blocks of j, in this case 20, with one catch trial per block randomly inserted

# %%
# libraries
from random import randrange, sample, choice, shuffle
import random

# %% [markdown]
# ### Trial Type Generator

# %%
# stimuli number
stimuli_num = 5

# %%
# trial types
trial_type_list = ["during", "after1", "after2"]

type_condition_dict = {
    "during": 3, # FF, FP, PP
    "after1": 2, # FF, PP
    "after2": 3 # FF, FP, PP
}

# %%
# block length
num_blocks = 10

# %%
def trial_type_length(trial_type):
    """Calculate the number of trials in each trial type"""
    return(stimuli_num**2 * type_condition_dict[trial_type])

# %%
def total_length(trial_type_list):
    """Function to calculate the length of the experiment, excluding catch trials"""
    total_length = 0
    for trial_type in trial_type_list:
        type_length = trial_type_length(trial_type)
        total_length += type_length
    return(total_length)

# %%
def trials_remaining_gen():
    """Make a dictionary containing the number of trials remaining for each trial condition"""
    trials_remaining_dict = {}
    for trial_type in type_condition_dict:
        trials_remaining_dict[trial_type] = trial_type_length(trial_type)
    return(trials_remaining_dict)

# %%
def choose_trial_type(trials_remaining_dict):
    """Function to select a trial type randomly out of the trials that remain"""
    # remove completed trial types from the dictionary
    for key, value in list(trials_remaining_dict.items()):
        if value == 0:
            del trials_remaining_dict[key]
    
    # return a randomly chosen trial from those that remain
    trial_choice = random.choice(list(trials_remaining_dict))
    return(trial_choice)

# %%
def add_catch(block_list):
    """Add a catch trial into a list in a random position"""
    block_list.insert(randrange(len(block_list)+1), "catch")
    return(block_list)

# %%
def trial_sequence_generator():
    """Function to generate the actual trial sequence we're going to use in the experiment"""
    block_length = int(total_length(trial_type_list)/num_blocks)
    
    trials_remaining_dict = trials_remaining_gen()
    
    trial_sequence = []
    
    for block in range(num_blocks):
        block_list = []
        for trial in range(block_length):
            # initially select a random assortment of trials from those that need to be added
            trial_type = choose_trial_type(trials_remaining_dict)
            trials_remaining_dict[trial_type] -= 1 # decrement the trial counter for that trial type
            block_list.append(trial_type)
        # add a catch trial into the list somewhere randomly
        block_list = add_catch(block_list)
        # add the block to the sequence
        trial_sequence.extend(block_list)
    
    return(trial_sequence)

# %%
def formatter(trial_sequence):
    """Place the trial sequence in the correct format for Inquisit 6"""
    output = "("
    
    for trial in trial_sequence:
        output = output + "\"" + trial + "\"," + "\n"
    output = output[:-2] # remove the last comma
    output = output + ")"
    
    return(output)

# %%
text = formatter(trial_sequence_generator())
print(text)
# Out:
# ("after1",
# "after1",
# "after1",
# "catch",
# "after1",
# "after2",
# "after2",
# "after1",
# "after1",
# "after1",
# "after1",
# "after2",
# "during",
# "during",
# "after2",
# "during",
# "during",
# "after1",
# "during",
# "after2",
# "after2",
# "after2",
# "after2",
# "after1",
# "after1",
# "after1",
# "catch",
# "after1",
# "during",
# "after2",
# "after2",
# "after2",
# "during",
# "after1",
# "during",
# "after1",
# "after2",
# "after1",
# "after1",
# "after2",
# "after1",
# "after1",
# "after1",
# "during",
# "during",
# "after2",
# "after1",
# "during",
# "catch",
# "during",
# "after1",
# "after1",
# "after1",
# "during",
# "after1",
# "after2",
# "after2",
# "after2",
# "during",
# "after2",
# "after2",
# "after2",
# "after1",
# "during",
# "after2",
# "after2",
# "during",
# "after2",
# "after1",
# "after2",
# "after2",
# "after1",
# "after1",
# "after1",
# "after1",
# "after2",
# "during",
# "catch",
# "during",
# "during",
# "after2",
# "after2",
# "after2",
# "after2",
# "after1",
# "after2",
# "after2",
# "after1",
# "during",
# "during",
# "after1",
# "after2",
# "catch",
# "after1",
# "after1",
# "after2",
# "after2",
# "after2",
# "during",
# "after2",
# "after1",
# "during",
# "during",
# "during",
# "during",
# "after1",
# "after1",
# "during",
# "during",
# "after1",
# "after1",
# "after1",
# "during",
# "after1",
# "during",
# "after2",
# "after1",
# "after2",
# "after1",
# "during",
# "catch",
# "after2",
# "after1",
# "after2",
# "during",
# "during",
# "after2",
# "after1",
# "after2",
# "after2",
# "after1",
# "during",
# "after1",
# "catch",
# "after1",
# "after2",
# "after2",
# "during",
# "after2",
# "during",
# "after2",
# "during",
# "during",
# "during",
# "after2",
# "after2",
# "after2",
# "after2",
# "during",
# "catch",
# "during",
# "during",
# "during",
# "during",
# "during",
# "during",
# "during",
# "during",
# "after2",
# "during",
# "during",
# "after2",
# "after2",
# "after2",
# "after2",
# "during",
# "during",
# "after2",
# "catch",
# "after2",
# "during",
# "after2",
# "during",
# "after2",
# "during",
# "during",
# "after2",
# "after2",
# "after2",
# "after2",
# "after2",
# "after2",
# "after2",
# "during",
# "during",
# "during",
# "after2",
# "during",
# "after2",
# "catch",
# "during",
# "during",
# "after2",
# "after2",
# "during",
# "during",
# "during",
# "during",
# "after2",
# "after2",
# "during",
# "after2",
# "during",
# "during",
# "during",
# "during",
# "during",
# "during",
# "during",
# "during")

# %%
trial_seq = eccen_color_formatter(trial_sequence_generator(), "sequence")
print(trial_seq)
# Out:
# <item sequence>
# /1 = "after2"
# /2 = "after1"
# /3 = "after1"
# /4 = "after1"
# /5 = "after1"
# /6 = "after2"
# /7 = "during"
# /8 = "catch"
# /9 = "after1"
# /10 = "after1"
# /11 = "after1"
# /12 = "during"
# /13 = "after1"
# /14 = "after2"
# /15 = "during"
# /16 = "after2"
# /17 = "after2"
# /18 = "during"
# /19 = "during"
# /20 = "during"
# /21 = "after2"
# /22 = "during"
# /23 = "after2"
# /24 = "catch"
# /25 = "during"
# /26 = "after1"
# /27 = "during"
# /28 = "after2"
# /29 = "after2"
# /30 = "after2"
# /31 = "after1"
# /32 = "during"
# /33 = "after1"
# /34 = "after1"
# /35 = "after1"
# /36 = "after2"
# /37 = "after2"
# /38 = "after2"
# /39 = "after1"
# /40 = "during"
# /41 = "during"
# /42 = "after1"
# /43 = "after2"
# /44 = "during"
# /45 = "catch"
# /46 = "after1"
# /47 = "after1"
# /48 = "after1"
# /49 = "after2"
# /50 = "after2"
# /51 = "after2"
# /52 = "after1"
# /53 = "after1"
# /54 = "after2"
# /55 = "after2"
# /56 = "after2"
# /57 = "after2"
# /58 = "after2"
# /59 = "during"
# /60 = "during"
# /61 = "after2"
# /62 = "after1"
# /63 = "during"
# /64 = "after2"
# /65 = "after2"
# /66 = "catch"
# /67 = "after2"
# /68 = "after1"
# /69 = "during"
# /70 = "after1"
# /71 = "during"
# /72 = "after1"
# /73 = "after1"
# /74 = "after2"
# /75 = "during"
# /76 = "after2"
# /77 = "after2"
# /78 = "after2"
# /79 = "during"
# /80 = "after1"
# /81 = "during"
# /82 = "during"
# /83 = "after2"
# /84 = "during"
# /85 = "after2"
# /86 = "after2"
# /87 = "catch"
# /88 = "after2"
# /89 = "during"
# /90 = "after1"
# /91 = "after2"
# /92 = "after1"
# /93 = "during"
# /94 = "after1"
# /95 = "during"
# /96 = "during"
# /97 = "during"
# /98 = "during"
# /99 = "after1"
# /100 = "after1"
# /101 = "after2"
# /102 = "after1"
# /103 = "during"
# /104 = "after2"
# /105 = "after1"
# /106 = "after1"
# /107 = "after1"
# /108 = "during"
# /109 = "catch"
# /110 = "during"
# /111 = "during"
# /112 = "during"
# /113 = "after1"
# /114 = "during"
# /115 = "after2"
# /116 = "after2"
# /117 = "after1"
# /118 = "after2"
# /119 = "after1"
# /120 = "after1"
# /121 = "after2"
# /122 = "after1"
# /123 = "after1"
# /124 = "after2"
# /125 = "after1"
# /126 = "after2"
# /127 = "catch"
# /128 = "after1"
# /129 = "during"
# /130 = "after1"
# /131 = "during"
# /132 = "after2"
# /133 = "during"
# /134 = "after2"
# /135 = "after2"
# /136 = "after2"
# /137 = "during"
# /138 = "after2"
# /139 = "after2"
# /140 = "after2"
# /141 = "after1"
# /142 = "during"
# /143 = "after2"
# /144 = "after2"
# /145 = "after1"
# /146 = "during"
# /147 = "after1"
# /148 = "after2"
# /149 = "during"
# /150 = "after2"
# /151 = "catch"
# /152 = "after1"
# /153 = "during"
# /154 = "after1"
# /155 = "after1"
# /156 = "after2"
# /157 = "after2"
# /158 = "after2"
# /159 = "during"
# /160 = "after2"
# /161 = "during"
# /162 = "during"
# /163 = "after2"
# /164 = "during"
# /165 = "during"
# /166 = "after2"
# /167 = "after2"
# /168 = "during"
# /169 = "after2"
# /170 = "after2"
# /171 = "after2"
# /172 = "after2"
# /173 = "during"
# /174 = "during"
# /175 = "during"
# /176 = "catch"
# /177 = "after2"
# /178 = "after2"
# /179 = "after2"
# /180 = "after2"
# /181 = "during"
# /182 = "after2"
# /183 = "after2"
# /184 = "after2"
# /185 = "after2"
# /186 = "after2"
# /187 = "during"
# /188 = "during"
# /189 = "during"
# /190 = "during"
# /191 = "after2"
# /192 = "during"
# /193 = "during"
# /194 = "during"
# /195 = "during"
# /196 = "during"
# /197 = "during"
# /198 = "during"
# /199 = "during"
# /200 = "during"
# /201 = "during"
# /202 = "during"
# /203 = "during"
# /204 = "during"
# /205 = "during"
# /206 = "during"
# /207 = "catch"
# /208 = "during"
# /209 = "during"
# /210 = "during"
# </item>

# %% [markdown]
# ### Trial Position Generator

# %%
# eccentricity types for each trial type
present_eccen = ["FF", "FP", "PP"]
after1_eccen = ["FF", "PP"]
after2_eccen = ["FF", "FP", "PP"]

# %%
# colour list
colours = ["1","2","3","7","8"]

# %%
def eccen_color_sequence_gen(trial_type):
    """Generate a random sequence of eccentricites, ensuring each one is present stimuli^2 times"""
    eccen_list = []
    for eccen in trial_type:
        for colour1 in colours:
            for colour2 in colours:
                eccen_list.append([eccen,colour1,colour2])
    random.shuffle(eccen_list)
    return(eccen_list)

# %%
def eccen_sequence_extractor(eccen_color_sequence,column):
    if(column=='eccen'):
        val = 0
    elif(column=='colour1'):
        val = 1
    elif(column=='colour2'):
        val = 2
        
    sequence = []
    for trial in eccen_color_sequence:
        sequence.append(trial[val])
    return(sequence)

# %%
def eccen_color_formatter(eccen_sequence, name):
    output = "<item " + name + ">\n"
    count = 1
    for trial in eccen_sequence:
        output += "/" + str(count) + " = " + "\"" + trial + "\"" + "\n"
        count += 1
    output += "</item>\n"
    return(output)

# %%
def eccen_color_printer(trial_type,name):
    sequence = eccen_color_sequence_gen(trial_type)
    print(eccen_color_formatter(eccen_sequence_extractor(sequence,'eccen'),name + "_eccen"))
    print(eccen_color_formatter(eccen_sequence_extractor(sequence,'colour1'),name + "_colour1"))
    print(eccen_color_formatter(eccen_sequence_extractor(sequence,'colour2'),name + "_colour2"))

# %%
eccen_color_printer(present_eccen,"present_during")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-61fd2bd5281e> in <module>
# ----> 1 eccen_color_printer(present_eccen,"present_during")
#
# <ipython-input-40-f423fee7a414> in eccen_color_printer(trial_type, name)
#       1 def eccen_color_printer(trial_type,name):
# ----> 2     sequence = eccen_color_sequence_gen(trial_type)
#       3     print(eccen_color_formatter(eccen_sequence_extractor(sequence,'eccen'),name + "_eccen"))
#       4     print(eccen_color_formatter(eccen_sequence_extractor(sequence,'colour1'),name + "_colour1"))
#       5     print(eccen_color_formatter(eccen_sequence_extractor(sequence,'colour2'),name + "_colour2"))
#
# <ipython-input-37-c966d9e6dffe> in eccen_color_sequence_gen(trial_type)
#       6             for colour2 in colours:
#       7                 eccen_list.append([eccen,colour1,colour2])
# ----> 8     random.shuffle(eccen_list)
#       9     return(eccen_list)
#
# NameError: name 'random' is not defined

# %%
eccen_color_printer(after1_eccen,"present_after1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-592b0d57a383> in <module>
# ----> 1 eccen_color_printer(after1_eccen,"present_after1")
#
# <ipython-input-40-f423fee7a414> in eccen_color_printer(trial_type, name)
#       1 def eccen_color_printer(trial_type,name):
# ----> 2     sequence = eccen_color_sequence_gen(trial_type)
#       3     print(eccen_color_formatter(eccen_sequence_extractor(sequence,'eccen'),name + "_eccen"))
#       4     print(eccen_color_formatter(eccen_sequence_extractor(sequence,'colour1'),name + "_colour1"))
#       5     print(eccen_color_formatter(eccen_sequence_extractor(sequence,'colour2'),name + "_colour2"))
#
# <ipython-input-37-c966d9e6dffe> in eccen_color_sequence_gen(trial_type)
#       6             for colour2 in colours:
#       7                 eccen_list.append([eccen,colour1,colour2])
# ----> 8     random.shuffle(eccen_list)
#       9     return(eccen_list)
#
# NameError: name 'random' is not defined

# %%
eccen_color_printer(after2_eccen,"present_after2")
